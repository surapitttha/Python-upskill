# %% [markdown]
# <a href="https://colab.research.google.com/github/surapitttha/Python-upskill/blob/main/Train_Test_Split.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train test split

# %%
from google.colab import drive

# Mount your Google Drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# ##Load dataset

# %%
import pandas as pd
df = pd.read_csv('/content/gdrive/MyDrive/dataset/data/simple_loan.csv')

df.head()
# Out:
#      age  employed own_house credit target
# 0  young     False         n   fair     no
# 1  young     False         n   good     no
# 2  young      True         n   good    yes
# 3  young      True         y   fair    yes
# 4  young     False         n   fair     no

# %%
df.isnull().sum()
# Out:
# age          0
# employed     0
# own_house    0
# credit       0
# target       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['age', 'employed', 'own_house', 'credit', 'target'], dtype='object')

# %%
X = df.drop('target',axis=1)
X
# Out:
#        age  employed own_house     credit
# 0    young     False         n       fair
# 1    young     False         n       good
# 2    young      True         n       good
# 3    young      True         y       fair
# 4    young     False         n       fair
# 5   middle     False         n       fair
# 6   middle     False         n       good
# 7   middle      True         y       good
# 8   middle     False         y  excellent
# 9   middle     False         y  excellent
# 10     old     False         y  excellent
# 11     old     False         y       good
# 12     old      True         n       good
# 13     old      True         n  excellent
# 14     old     False         n       fair
# 15     old     False         n  excellent
# 16   young      True         y       fair

# %%
y = df.target

# %% [markdown]
# ##split

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(X,y)

# %%
X.shape , y.shape
# Out:
# ((17, 4), (17,))

# %%
X_train.shape , y_train.shape
# Out:
# ((12, 4), (12,))

# %%
X_test.shape, y_test.shape
# Out:
# ((5, 4), (5,))

# %%
X_train.shape[0]+X_test.shape[0]
# Out:
# 17

# %%
y_train.shape[0]+y_test.shape[0]
# Out:
# 17

# %% [markdown]
# ## X_train and y_train

# %%
X_test
# Out:
#        age  employed own_house credit
# 3    young      True         y   fair
# 11     old     False         y   good
# 0    young     False         n   fair
# 4    young     False         n   fair
# 7   middle      True         y   good

# %%
y_train
# Out:
# 5      no
# 12    yes
# 15    yes
# 10    yes
# 16    yes
# 6      no
# 2     yes
# 13    yes
# 8     yes
# 14     no
# 1      no
# 9     yes
# Name: target, dtype: object

# %%
df.iloc[[1,2,3]]
# Out:
#      age  employed own_house credit target
# 1  young     False         n   good     no
# 2  young      True         n   good    yes
# 3  young      True         y   fair    yes

# %%
df.iloc

# %% [markdown]
# ## X_test and y_test

# %%
X_test
# Out:
#        age  employed own_house credit
# 3    young      True         y   fair
# 11     old     False         y   good
# 0    young     False         n   fair
# 4    young     False         n   fair
# 7   middle      True         y   good

# %%
y_test
# Out:
# 3     yes
# 11    yes
# 0      no
# 4      no
# 7     yes
# Name: target, dtype: object
